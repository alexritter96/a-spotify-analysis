# %%
import pandas as pd

# %%
df = pd.read_csv('21oogonwzxyof6vx67ekobkzy-65wJKvctNBSOaVrCrf1yMh.csv') 
df.head()
# Out:
#    energy  liveness    tempo  speechiness  acousticness  instrumentalness  \
# 0   0.733    0.8790  121.007       0.0355        0.3180             0.795
# 1   0.743    0.2210  170.083       0.0626        0.0356             0.847
# 2   0.627    0.0983  101.980       0.0350        0.1420             0.368
# 3   0.733    0.0750  138.050       0.0441        0.0108             0.756
# 4   0.785    0.1470   94.978       0.4250        0.0116             0.907
#
#    time_signature  danceability  key  duration_ms  loudness  valence  mode  \
# 0               3         0.655    5       281652    -9.777    0.646     0
# 1               5         0.567    8       212881    -8.614    0.423     1
# 2               4         0.746   11       258824    -7.652    0.242     0
# 3               4         0.570    7       250539   -11.771    0.347     0
# 4               4         0.533    4       282022    -7.226    0.378     0
#
#              type                                   uri
# ...
